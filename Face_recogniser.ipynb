# %% [markdown]
# <a href="https://colab.research.google.com/github/JessicaMishra/Face/blob/master/Face_recogniser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1af53e9f-c9e1-4104-bcec-a076670e5011" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1af53e9f-c9e1-4104-bcec-a076670e5011">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving WhatsApp1.mp4 to WhatsApp1.mp4

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from fastai.vision import *
from fastai.metrics import error_rate
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
img_counter=[]
img_counter.append(10)

# %%
from IPython.display import HTML
url = '/content/WhatsApp1.mp4'
HTML(f"""<video src={url} width=500 controls/>""")
# Out:
# <video src=/content/WhatsApp1.mp4 width=500 controls/>

# %%
import cv2 
import os 
  
# Read the video from specified path 
cam = cv2.VideoCapture("/content/WhatsApp1.mp4") 
  
try: 
      
    # creating a folder named data 
    if not os.path.exists('data'): 
        os.makedirs('data') 
  
# if not created then raise error 
except OSError: 
    print ('Error: Creating directory of data') 
  
# frame 
currentframe = 0
  
while(True): 
      
    # reading from frame 
    ret,frame = cam.read() 
  
    if ret: 
        # if video is still left continue creating images 
        name = './data/frame' + str(currentframe) + '.jpg'
        print ('Creating...' + name) 
        frame_rotate_90_clockwise = cv2.rotate(frame, cv2.ROTATE_90_CLOCKWISE)
        # writing the extracted images 
        cv2.imwrite(name, frame_rotate_90_clockwise) 
  
        # increasing counter so that it will 
        # show how many frames are created 
        currentframe += 1
    else: 
        break
  
# Release all space and windows once done 
cam.release() 
cv2.destroyAllWindows()
# Out:
# Creating..../data/frame0.jpg
# Creating..../data/frame1.jpg
# Creating..../data/frame2.jpg
# Creating..../data/frame3.jpg
# Creating..../data/frame4.jpg
# Creating..../data/frame5.jpg
# Creating..../data/frame6.jpg
# Creating..../data/frame7.jpg
# Creating..../data/frame8.jpg
# Creating..../data/frame9.jpg
# Creating..../data/frame10.jpg
# Creating..../data/frame11.jpg
# Creating..../data/frame12.jpg
# Creating..../data/frame13.jpg
# Creating..../data/frame14.jpg
# Creating..../data/frame15.jpg
# Creating..../data/frame16.jpg
# Creating..../data/frame17.jpg
# Creating..../data/frame18.jpg
# Creating..../data/frame19.jpg
# Creating..../data/frame20.jpg
# Creating..../data/frame21.jpg
# Creating..../data/frame22.jpg
# Creating..../data/frame23.jpg
# Creating..../data/frame24.jpg
# Creating..../data/frame25.jpg
# Creating..../data/frame26.jpg
# Creating..../data/frame27.jpg
# Creating..../data/frame28.jpg
# Creating..../data/frame29.jpg
# Creating..../data/frame30.jpg
# ...

# %%
import dlib
import cv2
import os
from imutils import face_utils
from PIL import Image
face_detector = dlib.get_frontal_face_detector()   
def face_finder(image_link):
  img=cv2.imread(image_link)
  frame = img
  gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
  rects = face_detector(gray,0)
  data=[]
  for rect in rects:
    (x1,y1,x2,y2) = face_utils.rect_to_bb(rect) 
    data.append([x1,y1,x2,y2])
  return face_cropper(image_link,data)
def face_cropper(image_link,rects):
  cropped_images=[]
  for rect in rects:
    my_image=Image.open(image_link)
    x1=rect[0]
    y1=rect[1]
    x2=rect[2]
    y2=rect[3]
    cropped_images.append(my_image.crop((x1,y1,x1+x2,y1+y2)))
  return cropped_images

# %%
os.makedirs('jessica')

# %%
i=0
files = os.listdir("/content/data/")
for file in files:
  try:
   img = face_finder("/content/data/"+file)
   img[0].save("/content/jessica/"+str(i)+".jpg")
   i+=1
  except:
    print("error")
# Out:
# error
# error

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d63019fa-e83a-48e0-b462-b9bd43472773" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d63019fa-e83a-48e0-b462-b9bd43472773">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
import pandas as pd
cred = pd.read_json("kaggle.json",lines=True)
os.environ['KAGGLE_USERNAME'] = cred.iloc[0][0]
os.environ['KAGGLE_KEY'] = cred.iloc[0][1]

# %%
# !kaggle datasets download -d hereisburak/pins-face-recognition
# Out:
# ...
#  98% 365M/372M [00:10<00:00, 37.3MB/s]
# 100% 372M/372M [00:11<00:00, 35.1MB/s]

# %%
# !unzip "*.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: 105_classes_pins_dataset/pins_Sophie Turner/Sophie Turner38_965.jpg
#   inflating: 105_classes_pins_dataset/pins_Sophie Turner/Sophie Turner39_966.jpg
#   inflating: 105_classes_pins_dataset/pins_Sophie Turner/Sophie Turner3_956.jpg
#   inflating: 105_classes_pins_dataset/pins_Sophie Turner/Sophie Turner41_968.jpg
#   inflating: 105_classes_pins_dataset/pins_Sophie Turner/Sophie Turner42_969.jpg
#   inflating: 105_classes_pins_dataset/pins_Sophie Turner/Sophie Turner44_970.jpg
#   inflating: 105_classes_pins_dataset/pins_Sophie Turner/Sophie Turner45_971.jpg
#   inflating: 105_classes_pins_dataset/pins_Sophie Turner/Sophie Turner46_972.jpg
#   inflating: 105_classes_pins_dataset/pins_Sophie Turner/Sophie Turner47_973.jpg
#   inflating: 105_classes_pins_dataset/pins_Sophie Turner/Sophie Turner48_974.jpg
#   inflating: 105_classes_pins_dataset/pins_Sophie Turner/Sophie Turner49_975.jpg
# ...

# %%
os.makedirs('notjessica')

# %%
inm=[]
j=0
tfiles=os.listdir("/content/105_classes_pins_dataset")
for file in tfiles:
  tfile1=os.listdir("/content/105_classes_pins_dataset/"+file)
  i=0
  for x in tfile1:
    if i==6:
      break
    else:
      colorImage  = Image.open("/content/105_classes_pins_dataset/"+file+"/"+x)
      colorImage.save("/content/notjessica/jessica"+str(j)+".jpg")
      i+=1
      j+=1

# %%
# !rm -rf notjessica

# %%
os.makedirs("face")

# %%
shutil.move("/content/notjessica", "/content/face")
# Out:
# '/content/face/notjessica'

# %%
shutil.move("/content/jessica", "/content/face")
# Out:
# '/content/face/jessica'

# %%
path=""
tfms = get_transforms()
data1 = ImageDataBunch.from_folder( Path("face"), valid_pct=0.2, bs=64, size=224, ds_tfms=get_transforms())

# %%
print(data1.classes)
len(data1.classes)
# Out:
# ['jessica', 'notjessica']
# 2

# %%
data1.classes, data1.c, len(data1.train_ds), len(data1.valid_ds)
# Out:
# (['jessica', 'notjessica'], 2, 1060, 264)

# %%
data1.show_batch(rows=5, figsize=(10,10))

# %%
resnet_learn = cnn_learner(data1, models.resnet50, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# ...

# %%
alexnet_learn=cnn_learner(data1, models.alexnet, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-4df8aa71.pth
# ...

# %%
mobilenetv2_learn=cnn_learner(data1, models.mobilenet_v2, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-b0353104.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-b0353104.pth
# ...

# %%
resnet_learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.210948</td>
#       <td>0.054271</td>
#       <td>0.018939</td>
#       <td>09:44</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.089273</td>
#       <td>0.000103</td>
#       <td>0.000000</td>
#       <td>09:52</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.050981</td>
#       <td>0.000005</td>
#       <td>0.000000</td>
#       <td>09:55</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.034483</td>
#       <td>0.000009</td>
#       <td>0.000000</td>
#       <td>09:48</td>
#     </tr>
#   </tbody>
# </table>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-274bffb3-28a4-4040-8833-5012478ab326" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-274bffb3-28a4-4040-8833-5012478ab326">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving t3.jfif to t3.jfif

# %%
test_image =open_image("t3.jfif")
test_image
# Out:
# Image (3, 1280, 720)

# %%
test_face = face_finder("t3.jfif")
test_face[0].save("test_face.jfif")
test_face[0]
# Out:
# <PIL.Image.Image image mode=RGB size=310x309 at 0x7F49E0EDB908>

# %%
my_image = open_image("test_face.jfif")

# %%
# %%time
pred_class,pred_idx,outputs = resnet_learn.predict(my_image)
print(pred_class)
# Out:
# jessica
# CPU times: user 231 ms, sys: 6.96 ms, total: 238 ms
# Wall time: 238 ms
